# %%
2firstName = "Samuel"
print(2firstName)
# Out:
#   Cell In[1], line 1
#     2firstName = "Samuel"
#     ^
# SyntaxError: invalid decimal literal

# %%
firstName = "Samuel" #String
print(firstName)
# Out:
# Samuel

# %%
first2Name = "Samuel"
print(first2Name)
# Out:
# Samuel

# %%
first Name = "Samuel"
print(first Name)
# Out:
#   Cell In[4], line 1
#     first Name = "Samuel"
#           ^
# SyntaxError: invalid syntax

# %%
first$Name = "Samuel"
print(first$Name)
# Out:
#   Cell In[5], line 1
#     first$Name = "Samuel"
#          ^
# SyntaxError: invalid syntax

# %%
_first_Name = "Samuel"
print(_first_Name)
# Out:
# Samuel

# %%
num = 10 #integer
NUM = 11
print(num, NUM)
# Out:
# 10 11

# %%
Sum_print = num + NUM
print(Sum_print)
# Out:
# 21

# %%
sum = num + NUM
print(sum)
# Out:
# 21

# %%
print = num + NUM
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 print = num + NUM
# ----> 2 print(print)
#
# TypeError: 'int' object is not callable

# %%
sum1 = firstName + num
print(sum1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sum1 = firstName + num
#       2 print(sum1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
secondName = "Adam" #String
sum_print = firstName + secondName
print(sum_print)
# Out:
# SamuelAdam

# %%
dec = 3.5 #float
print(dec + num)
# Out:
# 13.5

# %%
print(firstName + dec)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(firstName + dec)
#
# TypeError: can only concatenate str (not "float") to str

# %%
print(firstName , dec, num)
# Out:
# Samuel 3.5 10

# %%
number = 34.67
print(type(number))
# Out:
# <class 'float'>

# %%
print(type(firstName))
# Out:
# <class 'str'>

# %%
# Arithmetic Operators - +, -, *, /, %, //

# %%
print(number*num) #Multiplication
# Out:
# 346.70000000000005

# %%
print(number/num) #Division
# Out:
# 3.467

# %%
print(NUM/num)
# Out:
# 1.1

# %%
print(NUM*11.5)
# Out:
# 126.5

# %%
print(num % 3) #10%3 - Remainder(Modulus Operator)
# Out:
# 1

# %%
print(num // 2.5) # 10/2.5
# Out:
# 4.0

# %%
print(10.5/2.5)
# Out:
# 4.2

# %%
print(10.5 // 2.5) #floor division
# Out:
# 4.0

# %%
print(10 ** 2) # Power
# Out:
# 100

# %%
print(10 ^ 2) #Bitwise XOR Operator
# Out:
# 8

# %%
# Comparison Operator

# %%
n1 = 45.6
n2 = 50
print(n1 > n2) #greater than
# Out:
# False

# %%
# Boolean Datatype - True or False

# %%
print(n1 < n2) # 45.6 < 50 #less than
# Out:
# True

# %%
print(n1 == n2) # 45.6 = 50
# Out:
# False

# %%
print( n2 == n3) # 50 = 50
# Out:
# True

# %%
print(n1 != n2) # 45.6 != 50
# Out:
# True

# %%
print(n2 !=n3) # 50 != 50
# Out:
# False

# %%
n3 = 50
print(n2 <= n3) #greater than equal to
# Out:
# True

# %%
print(n2 >= n3) #less than equal to
# Out:
# True

# %%
# Logical Operators

# %%
# AND OPERATOR
X > Y AND Y > Z
Condition1  AND Condition2
TRUE AND TRUE -> TRUE
TRUE AND FALSE -> FALSE
FALSE AND TRUE -> FALSE
FALSE AND FALSE -> FALSE

# %%
c1 = 78
c2 = 89
c3 = 42.78
print(c1 < c2 and c2 > c3) # 78 < 89 and 89 > 42.78
# Out:
# True

# %%
print(c1 > c2 and c2 > c3) # 78 > 89 and 89 > 42.78
# Out:
# False

# %%
print(c1 > c2 and c2 < c3) # 78 > 89 and 89 < 42.78
# Out:
# False

# %%
# OR Operator
# not operator
# XOR operator

# %%
n1 = 'a' 
n2= 'A' 
n3= 'B'  
print(n1 == n2 and n2 == n3)
# Out:
# False

# %%
X > Y OR Y > Z
Condition1  OR Condition2
TRUE OR TRUE -> TRUE
TRUE OR FALSE -> TRUE
FALSE OR TRUE -> TRUE
FALSE AND FALSE -> FALSE

# %%
n1 = 56
n2 = 78.56
n3 = 89
n4 = 56
print(n1 > n2 or n2 < n3) #56 > 78.56 or 78.56 <89 -> FALSE or TRUE
# Out:
# True

# %%
print(n1 > n2 and n2 < n3)

# %%
print(n2 > n3 or n2 < n1)

# %%
print( n4 <= n1 or n4 < n1)

# %%
# NOT operator
NOT(TRUE) -> FALSE
NOT(FALSE) -> TRUE

# %%
print(not(n2 > n3 or n2 < n1)) #-> FALSE OR FALSE -> NOT(FALSE) -> TRUE
# Out:
# True

# %%
print(not(n2 > n3 or n2 > n1)) #-> FALSE or TRUE -> not(TRUE) ->FALSE
# Out:
# False

# %%
#XOR Operator
print(3 ^ 6)
# Out:
# 5

# %%
print(6 ^ 8)
# Out:
# 14

# %%
# Assignment operator

# %%
x = 10

# %%
x += 5
print(x)
# Out:
# 20

# %%
x -= 3
print(x)
# Out:
# 17

# %%
x *= 4
print(x)
# Out:
# 68
